# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana110404/SCT_DS_1/blob/main/SCT_DS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Sample data
ages = [10,25,40,55,70,85,100,115,130,145,160,175,190,205,215]
genders = ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']

# Create a Pandas DataFrame
df = pd.DataFrame({'Age': ages, 'Gender': genders})

# Create a histogram for the continuous variable (Age)
plt.hist(df['Age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.show()
